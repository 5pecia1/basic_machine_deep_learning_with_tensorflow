# %% [markdown]
# # Hypothesis and cost fucntion
#
# $$ H(x) = Wx + b$$
# $$ cost(W,b) = \frac{1}{m}\sum\limits_{i=1}^m (H(x^{(i)}) - y^{(i)})^2$$
#
# * 학습에서의 목표
#
#   cost를 가장 작게하는 W, b를 구하는것이다

# %%
import tensorflow as tf

# %% [markdown]
# 학습 데이터를 준다

# %%
x_data = [1,2,3,4]
y_data = [1,2,3,4]

# %% [markdown]
# $W$와 $b$의 값을 variable로 지정한다
# variable로 지정을 해야 나중에 모델이 업데이트를 할 수 있다.
# 처음에는 $W$와 $b$에 랜덤한 값(-1 ~ 1)을 준다

# %%
# Try to find values for W and b that compute y_data = w * x_data + b
# (We know that W should be 1 and 0, but Tensorflow will
# figure that out for us.)
W = tf.Variable(tf.random_uniform([1], -1.0, 1.0))
b = tf.Variable(tf.random_uniform([1], -1.0, 1.0))

# %% [markdown]
# $$H(x) = Wx + b$$

# %%
# Our hypothesis
hypothesis = W * x_data + b

# %% [markdown]
# $$ cost(W,b) = \frac{1}{m}\sum\limits_{i=1}^m (H(x^{(i)}) - y^{(i)})^2$$

# %%
# Simplified cost function
cost = tf.reduce_mean(tf.square(hypothesis - y_data))

# %% [markdown]
# 약간 매직이라고 생각하면 된다.
# gradientDescentOpimizer를 이용해서 cost를 최소환 한다고 생각하면 된다

# %%
# Minimize
a = tf.Variable(0.1) # Learning rate, alpha
optimizer = tf.train.GradientDescentOptimizer(a)
train = optimizer.minimize(cost)

# %% [markdown]
# 변수를 초기화 시킨다
# 초기화 시키지 않으면 에러가 난다.

# %%
# Simplified cost functino
init = tf.initialize_all_variables()

# %%
# Launch the graph
sess = tf.Session()
sess.run(init)

# %% [markdown]
# loop를 2000번 돌면서
# w, b를 찾는다
# 20번 마다 cost,w,b 값이 어떻게 되는지 보여준다

# %%
for step in range(2001):
    sess.run(train)
    if step % 20 == 0:
        print (step, sess.run(cost), sess.run(W), sess.run(b))
# Out:
# 0 0.564859 [ 1.00225198] [ 0.74593693]
# 20 0.0220872 [ 0.87638748] [ 0.36368623]
# 40 0.0065479 [ 0.93265408] [ 0.19800521]
# 60 0.00194117 [ 0.96333152] [ 0.10780955]
# 80 0.000575472 [ 0.98003489] [ 0.05870001]
# 100 0.000170602 [ 0.98912942] [ 0.03196087]
# 120 5.05766e-05 [ 0.9940812] [ 0.01740199]
# 140 1.49937e-05 [ 0.9967773] [ 0.00947502]
# 160 4.44513e-06 [ 0.9982453] [ 0.00515894]
# 180 1.31772e-06 [ 0.99904466] [ 0.00280898]
# 200 3.90616e-07 [ 0.99947983] [ 0.00152943]
# 220 1.1583e-07 [ 0.99971676] [ 0.00083274]
# 240 3.434e-08 [ 0.99984586] [ 0.00045344]
# 260 1.01793e-08 [ 0.99991608] [ 0.00024688]
# 280 3.01432e-09 [ 0.99995428] [ 0.00013441]
# 300 8.97359e-10 [ 0.99997514] [  7.31945329e-05]
# 320 2.66244e-10 [ 0.99998647] [  3.98636221e-05]
# 340 7.86429e-11 [ 0.99999261] [  2.16842091e-05]
# 360 2.32205e-11 [ 0.99999601] [  1.18256003e-05]
# 380 6.69687e-12 [ 0.99999779] [  6.41349743e-06]
# 400 1.99307e-12 [ 0.99999881] [  3.51075141e-06]
# 420 6.14619e-13 [ 0.9999994] [  1.93718870e-06]
# 440 1.98952e-13 [ 0.9999997] [  1.04311914e-06]
# 460 1.03029e-13 [ 0.99999976] [  5.48400749e-07]
# 480 4.26326e-14 [ 0.99999988] [  3.15942543e-07]
# 500 3.19744e-14 [ 0.99999988] [  2.44416981e-07]
# 520 3.55271e-15 [ 0.99999994] [  1.78851948e-07]
# 540 3.55271e-15 [ 1.] [  1.13286909e-07]
# 560 0.0 [ 1.] [  5.36822498e-08]
# 580 0.0 [ 1.] [  5.36822498e-08]
# 1880 0.0 [ 1.] [  5.36822498e-08]
# 1900 0.0 [ 1.] [  5.36822498e-08]
# 1920 0.0 [ 1.] [  5.36822498e-08]
# 1940 0.0 [ 1.] [  5.36822498e-08]
# 1960 0.0 [ 1.] [  5.36822498e-08]
# 1980 0.0 [ 1.] [  5.36822498e-08]
# 2000 0.0 [ 1.] [  5.36822498e-08]

# %% [markdown]
# ### Placeholder를 이용해 보자

# %%
X = tf.placeholder(tf.float32)
Y = tf.placeholder(tf.float32)

# %%
# Our hypothesis
hypothesis = W * X + b

# Simplified cost function
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# Minimize
a = tf.Variable(0.1) # Learning rate, alpha
optimizer = tf.train.GradientDescentOptimizer(a)
train = optimizer.minimize(cost)

# Simplified cost functino
init = tf.initialize_all_variables()

# Launch the graph
sess = tf.Session()
sess.run(init)

for step in range(2001):
    sess.run(train, feed_dict={X:x_data, Y:y_data})
    if step % 20 == 0:
        print (step, sess.run(cost, feed_dict={X:x_data, Y:y_data}), sess.run(W), sess.run(b))
# Out:
# 0 9.07792 [ 1.82928085] [ 0.79355282]
# 20 0.0104077 [ 0.91542619] [ 0.24973315]
# 40 0.00308514 [ 0.9537729] [ 0.1359136]
# 60 0.000914607 [ 0.97483021] [ 0.07400201]
# 80 0.000271144 [ 0.98629564] [ 0.04029252]
# 100 8.03822e-05 [ 0.99253827] [ 0.0219384]
# 120 2.38293e-05 [ 0.99593729] [ 0.011945]
# 140 7.06454e-06 [ 0.99778795] [ 0.00650378]
# 160 2.09422e-06 [ 0.99879563] [ 0.00354116]
# 180 6.20786e-07 [ 0.99934429] [ 0.00192808]
# 200 1.84091e-07 [ 0.99964291] [ 0.00104978]
# 220 5.4565e-08 [ 0.99980563] [ 0.00057163]
# 240 1.6183e-08 [ 0.99989408] [ 0.00031121]
# 260 4.79325e-09 [ 0.9999423] [ 0.00016943]
# 280 1.4185e-09 [ 0.99996859] [  9.22462277e-05]
# 300 4.2067e-10 [ 0.99998289] [  5.02189978e-05]
# 320 1.24288e-10 [ 0.99999076] [  2.73486930e-05]
# 340 3.71472e-11 [ 0.99999493] [  1.48615236e-05]
# 360 1.09601e-11 [ 0.99999726] [  8.12023700e-06]
# 380 3.24363e-12 [ 0.99999851] [  4.42474902e-06]
# 400 1.0516e-12 [ 0.99999923] [  2.40415193e-06]
# 420 2.8777e-13 [ 0.99999952] [  1.32530818e-06]
# 440 8.52651e-14 [ 0.99999976] [  6.99459406e-07]
# 460 2.84217e-14 [ 0.99999988] [  3.83554749e-07]
# 480 2.84217e-14 [ 0.99999994] [  2.82226836e-07]
# 500 3.55271e-15 [ 0.99999994] [  2.10701316e-07]
# 520 2.84217e-14 [ 0.99999994] [  1.03413043e-07]
# 540 0.0 [ 1.] [  5.57293234e-08]
# 560 0.0 [ 1.] [  5.57293234e-08]
# 580 0.0 [ 1.] [  5.57293234e-08]
# 600 0.0 [ 1.] [  5.57293234e-08]
# 620 0.0 [ 1.] [  5.57293234e-08]
# 640 0.0 [ 1.] [  5.57293234e-08]
# 660 0.0 [ 1.] [  5.57293234e-08]
# 680 0.0 [ 1.] [  5.57293234e-08]
# 700 0.0 [ 1.] [  5.57293234e-08]
# 720 0.0 [ 1.] [  5.57293234e-08]
# 740 0.0 [ 1.] [  5.57293234e-08]
# 760 0.0 [ 1.] [  5.57293234e-08]
# 780 0.0 [ 1.] [  5.57293234e-08]
# 800 0.0 [ 1.] [  5.57293234e-08]
# 820 0.0 [ 1.] [  5.57293234e-08]
# 840 0.0 [ 1.] [  5.57293234e-08]
# 860 0.0 [ 1.] [  5.57293234e-08]
# 880 0.0 [ 1.] [  5.57293234e-08]
# 900 0.0 [ 1.] [  5.57293234e-08]
# 920 0.0 [ 1.] [  5.57293234e-08]
# 940 0.0 [ 1.] [  5.57293234e-08]
# 960 0.0 [ 1.] [  5.57293234e-08]
# 980 0.0 [ 1.] [  5.57293234e-08]
# 1000 0.0 [ 1.] [  5.57293234e-08]
# 1020 0.0 [ 1.] [  5.57293234e-08]
# 1040 0.0 [ 1.] [  5.57293234e-08]
# 1060 0.0 [ 1.] [  5.57293234e-08]
# 1080 0.0 [ 1.] [  5.57293234e-08]
# 1100 0.0 [ 1.] [  5.57293234e-08]
# 1120 0.0 [ 1.] [  5.57293234e-08]
# 1140 0.0 [ 1.] [  5.57293234e-08]
# 1160 0.0 [ 1.] [  5.57293234e-08]
# 1180 0.0 [ 1.] [  5.57293234e-08]
# 1200 0.0 [ 1.] [  5.57293234e-08]
# 1220 0.0 [ 1.] [  5.57293234e-08]
# 1240 0.0 [ 1.] [  5.57293234e-08]
# 1260 0.0 [ 1.] [  5.57293234e-08]
# 1280 0.0 [ 1.] [  5.57293234e-08]
# 1300 0.0 [ 1.] [  5.57293234e-08]
# 1320 0.0 [ 1.] [  5.57293234e-08]
# 1340 0.0 [ 1.] [  5.57293234e-08]
# 1360 0.0 [ 1.] [  5.57293234e-08]
# 1380 0.0 [ 1.] [  5.57293234e-08]
# 1400 0.0 [ 1.] [  5.57293234e-08]
# 1420 0.0 [ 1.] [  5.57293234e-08]
# 1440 0.0 [ 1.] [  5.57293234e-08]
# 1460 0.0 [ 1.] [  5.57293234e-08]
# 1480 0.0 [ 1.] [  5.57293234e-08]
# 1500 0.0 [ 1.] [  5.57293234e-08]
# 1520 0.0 [ 1.] [  5.57293234e-08]
# 1540 0.0 [ 1.] [  5.57293234e-08]
# 1560 0.0 [ 1.] [  5.57293234e-08]
# 1580 0.0 [ 1.] [  5.57293234e-08]
# 1600 0.0 [ 1.] [  5.57293234e-08]
# 1620 0.0 [ 1.] [  5.57293234e-08]
# 1640 0.0 [ 1.] [  5.57293234e-08]
# 1660 0.0 [ 1.] [  5.57293234e-08]
# 1680 0.0 [ 1.] [  5.57293234e-08]
# 1700 0.0 [ 1.] [  5.57293234e-08]
# 1720 0.0 [ 1.] [  5.57293234e-08]
# 1740 0.0 [ 1.] [  5.57293234e-08]
# 1760 0.0 [ 1.] [  5.57293234e-08]
# 1780 0.0 [ 1.] [  5.57293234e-08]
# 1800 0.0 [ 1.] [  5.57293234e-08]
# 1820 0.0 [ 1.] [  5.57293234e-08]
# 1840 0.0 [ 1.] [  5.57293234e-08]
# 1860 0.0 [ 1.] [  5.57293234e-08]
# 1880 0.0 [ 1.] [  5.57293234e-08]
# 1900 0.0 [ 1.] [  5.57293234e-08]
# 1920 0.0 [ 1.] [  5.57293234e-08]
# 1940 0.0 [ 1.] [  5.57293234e-08]
# 1960 0.0 [ 1.] [  5.57293234e-08]
# 1980 0.0 [ 1.] [  5.57293234e-08]
# 2000 0.0 [ 1.] [  5.57293234e-08]

# %% [markdown]
# 예측하는 모델로 사용한다.
# 모델을 작성 할 필요가 없다
#
# X 값이 얼마일때 Y값은 얼마일까?

# %%
# learns best fit is W:[1], b= [0]
print (sess.run(hypothesis, feed_dict={X:5}))
print (sess.run(hypothesis, feed_dict={X:2.5}))
# Out:
# [ 5.]
# [ 2.5]
